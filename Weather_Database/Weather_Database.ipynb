# %%
#Importing the dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Import the Citipy Module
from citipy import citipy
import requests

#Import the request library
import requests

#Import API key
from config import weather_api_key

# %%
# Initializing URL for our personal Weather Map API Call link
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Creating a new set of randomized lat and long combinations
lats = np.random.uniform (low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform (low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Adding all our randomized lat and long comibations into a list format 
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Using citipy to search for the closest city for each lat and long combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# We are looking to find the number of unique cities that we are able to pull up
len(cities)
# Out:
# 781

# %%
# Check to see if our program is working for two cities
# City 1 = Boston 

check_url = url + "&q=Boston"
city_data_check = requests.get(check_url).json()
city_data_check
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 70.97,
#   'feels_like': 70.16,
#   'temp_min': 66.94,
#   'temp_max': 74.39,
#   'pressure': 1021,
#   'humidity': 51},
#  'visibility': 10000,
#  'wind': {'speed': 4, 'deg': 90, 'gust': 8.01},
#  'clouds': {'all': 61},
#  'dt': 1655333787,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1655284013,
#   'sunset': 1655338961},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# City 2 = Toronto

check_url = url + "&q=Toronto"
city_data_check = requests.get(check_url).json()
city_data_check
# Out:
# {'coord': {'lon': -79.4163, 'lat': 43.7001},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 74.77,
#   'feels_like': 75.04,
#   'temp_min': 70.16,
#   'temp_max': 76.24,
#   'pressure': 1013,
#   'humidity': 66},
#  'visibility': 10000,
#  'wind': {'speed': 7, 'deg': 124, 'gust': 11.99},
#  'clouds': {'all': 81},
#  'dt': 1655334002,
#  'sys': {'type': 2,
#   'id': 2043365,
#   'country': 'CA',
#   'sunrise': 1655285724,
#   'sunset': 1655341262},
#  'timezone': -14400,
#  'id': 6167865,
#  'name': 'Toronto',
#  'cod': 200}

# %%
# Create an empty list which will hold our weather data 
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Counters 
record_count = 1
set_count = 1

# Loop through the various city lists 
for i, city in enumerate(cities):

    # Group the various city in set of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Creating a URL for each of the cities in our list
    city_url = url + "&q=" + city.replace(" ","+")

    # Logging the URL in  
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # We are making an API request for each city 
    try:
        
        # Compiling the JSON data
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
       # Organizing the various city data under the following categories
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,})

    # Statement below is required in the event of an error occuring 
    except:
        print("City not found. Skipping...")
        pass

# Data retrieval process is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | batemans bay
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | saint anthony
# Processing Record 7 of Set 1 | coihaique
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | saint george
# Processing Record 11 of Set 1 | dieppe
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | narsaq
# Processing Record 14 of Set 1 | dunedin
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | grindavik
# Processing Record 17 of Set 1 | krasnoselkup
# Processing Record 18 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | shaunavon
# Processing Record 21 of Set 1 | arraial do cabo
# Processing Record 22 of Set 1 | chumikan
# Processing Record 23 of Set 1 | ahuimanu
# Processing Record 24 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | ilulissat
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | margate
# Processing Record 29 of Set 1 | meadow lake
# Processing Record 30 of Set 1 | zhigansk
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 1 | sao felix do xingu
# Processing Record 34 of Set 1 | goundam
# Processing Record 35 of Set 1 | chara
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | pacific grove
# Processing Record 39 of Set 1 | tiksi
# Processing Record 40 of Set 1 | mount gambier
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | palu
# Processing Record 44 of Set 1 | sorland
# Processing Record 45 of Set 1 | constitucion
# Processing Record 46 of Set 1 | pisco
# Processing Record 47 of Set 1 | lar
# Processing Record 48 of Set 1 | naryan-mar
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | guaruja
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | ilorin
# Processing Record 6 of Set 2 | bethanien
# Processing Record 7 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 8 of Set 2 | mehamn
# Processing Record 9 of Set 2 | derzhavinsk
# Processing Record 10 of Set 2 | rikitea
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | brownsville
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | podgorenskiy
# Processing Record 16 of Set 2 | jawhar
# Processing Record 17 of Set 2 | samarai
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | husavik
# Processing Record 20 of Set 2 | kruisfontein
# Processing Record 21 of Set 2 | tessalit
# Processing Record 22 of Set 2 | san patricio
# Processing Record 23 of Set 2 | fare
# Processing Record 24 of Set 2 | kahului
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | yulara
# Processing Record 27 of Set 2 | batagay-alyta
# Processing Record 28 of Set 2 | ponta do sol
# Processing Record 29 of Set 2 | moose factory
# Processing Record 30 of Set 2 | melilla
# Processing Record 31 of Set 2 | longyearbyen
# Processing Record 32 of Set 2 | bengkulu
# Processing Record 33 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 2 | torbay
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | saskylakh
# Processing Record 37 of Set 2 | nanortalik
# Processing Record 38 of Set 2 | port macquarie
# Processing Record 39 of Set 2 | korla
# Processing Record 40 of Set 2 | buala
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | mahebourg
# Processing Record 43 of Set 2 | arys
# Processing Record 44 of Set 2 | ishigaki
# Processing Record 45 of Set 2 | palmer
# Processing Record 46 of Set 2 | khandbari
# Processing Record 47 of Set 2 | mullaitivu
# City not found. Skipping...
# Processing Record 48 of Set 2 | sassandra
# Processing Record 49 of Set 2 | jizan
# Processing Record 50 of Set 2 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 1 of Set 3 | qaqortoq
# Processing Record 2 of Set 3 | hauknes
# Processing Record 3 of Set 3 | mar del plata
# Processing Record 4 of Set 3 | isoka
# Processing Record 5 of Set 3 | sur
# Processing Record 6 of Set 3 | katsuura
# Processing Record 7 of Set 3 | beira
# Processing Record 8 of Set 3 | beringovskiy
# Processing Record 9 of Set 3 | kutum
# Processing Record 10 of Set 3 | starosubkhangulovo
# Processing Record 11 of Set 3 | saint-pierre
# Processing Record 12 of Set 3 | rawlins
# Processing Record 13 of Set 3 | buraydah
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | provideniya
# Processing Record 17 of Set 3 | emba
# Processing Record 18 of Set 3 | kulebaki
# Processing Record 19 of Set 3 | santa fe
# Processing Record 20 of Set 3 | pitimbu
# Processing Record 21 of Set 3 | fairbanks
# Processing Record 22 of Set 3 | nyurba
# Processing Record 23 of Set 3 | colesberg
# Processing Record 24 of Set 3 | ahipara
# Processing Record 25 of Set 3 | genhe
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | tasiilaq
# Processing Record 29 of Set 3 | baculin
# Processing Record 30 of Set 3 | port hardy
# Processing Record 31 of Set 3 | mosetse
# Processing Record 32 of Set 3 | tromso
# Processing Record 33 of Set 3 | dubai
# Processing Record 34 of Set 3 | umm kaddadah
# Processing Record 35 of Set 3 | hilo
# Processing Record 36 of Set 3 | te anau
# Processing Record 37 of Set 3 | mach
# Processing Record 38 of Set 3 | laramie
# Processing Record 39 of Set 3 | victoria
# Processing Record 40 of Set 3 | faanui
# Processing Record 41 of Set 3 | bantry
# Processing Record 42 of Set 3 | akcaabat
# Processing Record 43 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | shimoda
# Processing Record 45 of Set 3 | osmena
# Processing Record 46 of Set 3 | codrington
# Processing Record 47 of Set 3 | coria
# Processing Record 48 of Set 3 | luchow
# Processing Record 49 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 3 | maua
# Processing Record 1 of Set 4 | naze
# Processing Record 2 of Set 4 | port hedland
# Processing Record 3 of Set 4 | coquimbo
# Processing Record 4 of Set 4 | axim
# Processing Record 5 of Set 4 | barrow
# Processing Record 6 of Set 4 | havre-saint-pierre
# Processing Record 7 of Set 4 | eskasem
# City not found. Skipping...
# Processing Record 8 of Set 4 | solnechnyy
# Processing Record 9 of Set 4 | alofi
# Processing Record 10 of Set 4 | hobart
# Processing Record 11 of Set 4 | la ronge
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | menongue
# Processing Record 14 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 4 | rocha
# Processing Record 16 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 4 | stornoway
# Processing Record 18 of Set 4 | yerbogachen
# Processing Record 19 of Set 4 | alnashi
# Processing Record 20 of Set 4 | cabedelo
# Processing Record 21 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 22 of Set 4 | airai
# Processing Record 23 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 4 | souillac
# Processing Record 25 of Set 4 | verkhoyansk
# Processing Record 26 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 27 of Set 4 | namtsy
# Processing Record 28 of Set 4 | ostrovnoy
# Processing Record 29 of Set 4 | itarema
# Processing Record 30 of Set 4 | port lincoln
# Processing Record 31 of Set 4 | pangoa
# Processing Record 32 of Set 4 | kousseri
# Processing Record 33 of Set 4 | waiuku
# Processing Record 34 of Set 4 | lavrentiya
# Processing Record 35 of Set 4 | usinsk
# Processing Record 36 of Set 4 | mumbwa
# Processing Record 37 of Set 4 | nome
# Processing Record 38 of Set 4 | cascais
# Processing Record 39 of Set 4 | vredendal
# Processing Record 40 of Set 4 | caravelas
# Processing Record 41 of Set 4 | salalah
# Processing Record 42 of Set 4 | gigmoto
# Processing Record 43 of Set 4 | cacu
# Processing Record 44 of Set 4 | porto nacional
# Processing Record 45 of Set 4 | le moule
# Processing Record 46 of Set 4 | port alfred
# Processing Record 47 of Set 4 | kodiak
# Processing Record 48 of Set 4 | sokolka
# Processing Record 49 of Set 4 | rio gallegos
# Processing Record 50 of Set 4 | dwarka
# Processing Record 1 of Set 5 | xiaoweizhai
# Processing Record 2 of Set 5 | cidreira
# Processing Record 3 of Set 5 | inirida
# Processing Record 4 of Set 5 | ashland
# Processing Record 5 of Set 5 | giyani
# Processing Record 6 of Set 5 | bambous virieux
# Processing Record 7 of Set 5 | upernavik
# Processing Record 8 of Set 5 | lorengau
# Processing Record 9 of Set 5 | melville
# Processing Record 10 of Set 5 | moyale
# Processing Record 11 of Set 5 | acari
# Processing Record 12 of Set 5 | hambantota
# Processing Record 13 of Set 5 | miri
# Processing Record 14 of Set 5 | santarem
# Processing Record 15 of Set 5 | norman wells
# Processing Record 16 of Set 5 | qaanaaq
# Processing Record 17 of Set 5 | chilmari
# Processing Record 18 of Set 5 | new norfolk
# Processing Record 19 of Set 5 | huangchuan
# Processing Record 20 of Set 5 | quatre cocos
# Processing Record 21 of Set 5 | matara
# Processing Record 22 of Set 5 | mudgee
# Processing Record 23 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 5 | grand gaube
# Processing Record 25 of Set 5 | aksu
# Processing Record 26 of Set 5 | russell
# Processing Record 27 of Set 5 | thompson
# Processing Record 28 of Set 5 | wajir
# Processing Record 29 of Set 5 | kerteh
# City not found. Skipping...
# Processing Record 30 of Set 5 | arara
# Processing Record 31 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 5 | keti bandar
# Processing Record 33 of Set 5 | maputo
# Processing Record 34 of Set 5 | egvekinot
# Processing Record 35 of Set 5 | dingle
# Processing Record 36 of Set 5 | nikolskoye
# Processing Record 37 of Set 5 | castro
# Processing Record 38 of Set 5 | piracuruca
# Processing Record 39 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 5 | ancud
# Processing Record 41 of Set 5 | elizabeth city
# Processing Record 42 of Set 5 | cabo san lucas
# Processing Record 43 of Set 5 | kommunisticheskiy
# Processing Record 44 of Set 5 | kilis
# Processing Record 45 of Set 5 | aykhal
# Processing Record 46 of Set 5 | jonesboro
# Processing Record 47 of Set 5 | biak
# Processing Record 48 of Set 5 | bathsheba
# Processing Record 49 of Set 5 | sabang
# Processing Record 50 of Set 5 | saldanha
# Processing Record 1 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 6 | namatanai
# Processing Record 3 of Set 6 | cherskiy
# Processing Record 4 of Set 6 | muhos
# Processing Record 5 of Set 6 | paita
# Processing Record 6 of Set 6 | mgandu
# Processing Record 7 of Set 6 | vostok
# Processing Record 8 of Set 6 | dolores
# Processing Record 9 of Set 6 | jalu
# Processing Record 10 of Set 6 | kudahuvadhoo
# Processing Record 11 of Set 6 | lubumbashi
# Processing Record 12 of Set 6 | kiboga
# Processing Record 13 of Set 6 | ciudad bolivar
# Processing Record 14 of Set 6 | mana
# Processing Record 15 of Set 6 | stillwater
# Processing Record 16 of Set 6 | colares
# Processing Record 17 of Set 6 | rabo de peixe
# Processing Record 18 of Set 6 | itamaraca
# Processing Record 19 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 6 | nuuk
# Processing Record 21 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 6 | jiwani
# Processing Record 24 of Set 6 | loandjili
# Processing Record 25 of Set 6 | riyadh
# Processing Record 26 of Set 6 | chokurdakh
# Processing Record 27 of Set 6 | oranjemund
# Processing Record 28 of Set 6 | pires do rio
# Processing Record 29 of Set 6 | meoqui
# Processing Record 30 of Set 6 | tselinnoye
# Processing Record 31 of Set 6 | agadez
# Processing Record 32 of Set 6 | bowen
# Processing Record 33 of Set 6 | walvis bay
# Processing Record 34 of Set 6 | klyuchi
# Processing Record 35 of Set 6 | zhangzhou
# Processing Record 36 of Set 6 | altamira
# Processing Record 37 of Set 6 | hun
# Processing Record 38 of Set 6 | salinas
# Processing Record 39 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 40 of Set 6 | nata
# Processing Record 41 of Set 6 | thunder bay
# Processing Record 42 of Set 6 | kalmunai
# Processing Record 43 of Set 6 | portland
# Processing Record 44 of Set 6 | west odessa
# Processing Record 45 of Set 6 | solsvik
# City not found. Skipping...
# Processing Record 46 of Set 6 | juneau
# Processing Record 47 of Set 6 | banja luka
# Processing Record 48 of Set 6 | asau
# Processing Record 49 of Set 6 | nisia floresta
# Processing Record 50 of Set 6 | padang
# Processing Record 1 of Set 7 | dong xoai
# Processing Record 2 of Set 7 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 7 | uvarovka
# Processing Record 4 of Set 7 | lakes entrance
# Processing Record 5 of Set 7 | khash
# Processing Record 6 of Set 7 | ribeira grande
# Processing Record 7 of Set 7 | port blair
# Processing Record 8 of Set 7 | arlit
# Processing Record 9 of Set 7 | nicoya
# Processing Record 10 of Set 7 | homer
# Processing Record 11 of Set 7 | guerrero negro
# Processing Record 12 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 7 | talnakh
# Processing Record 14 of Set 7 | bilma
# Processing Record 15 of Set 7 | nyahururu
# Processing Record 16 of Set 7 | lethem
# Processing Record 17 of Set 7 | praia
# Processing Record 18 of Set 7 | lumeje
# Processing Record 19 of Set 7 | banjar
# Processing Record 20 of Set 7 | cadillac
# Processing Record 21 of Set 7 | hongjiang
# Processing Record 22 of Set 7 | myaundzha
# Processing Record 23 of Set 7 | marystown
# Processing Record 24 of Set 7 | kupino
# Processing Record 25 of Set 7 | wichita falls
# Processing Record 26 of Set 7 | klaksvik
# Processing Record 27 of Set 7 | kaeo
# Processing Record 28 of Set 7 | oranjestad
# Processing Record 29 of Set 7 | sanming
# Processing Record 30 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 7 | ambanja
# Processing Record 32 of Set 7 | sanwer
# Processing Record 33 of Set 7 | goderich
# Processing Record 34 of Set 7 | dangriga
# Processing Record 35 of Set 7 | komsomolskiy
# Processing Record 36 of Set 7 | chicama
# Processing Record 37 of Set 7 | gunjur
# Processing Record 38 of Set 7 | dongsheng
# Processing Record 39 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 7 | conde
# Processing Record 41 of Set 7 | pevek
# Processing Record 42 of Set 7 | tomatlan
# Processing Record 43 of Set 7 | indramayu
# Processing Record 44 of Set 7 | nampula
# Processing Record 45 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 7 | limbuhan
# Processing Record 47 of Set 7 | yeletskiy
# City not found. Skipping...
# Processing Record 48 of Set 7 | nishihara
# Processing Record 49 of Set 7 | bonavista
# Processing Record 50 of Set 7 | viedma
# Processing Record 1 of Set 8 | acapulco
# Processing Record 2 of Set 8 | kununurra
# Processing Record 3 of Set 8 | cayenne
# Processing Record 4 of Set 8 | hasaki
# Processing Record 5 of Set 8 | waingapu
# Processing Record 6 of Set 8 | broken hill
# Processing Record 7 of Set 8 | agboville
# Processing Record 8 of Set 8 | caraquet
# Processing Record 9 of Set 8 | do gonbadan
# Processing Record 10 of Set 8 | hualmay
# Processing Record 11 of Set 8 | orsk
# Processing Record 12 of Set 8 | igboho
# Processing Record 13 of Set 8 | ust-ordynskiy
# Processing Record 14 of Set 8 | luderitz
# Processing Record 15 of Set 8 | kangaatsiaq
# Processing Record 16 of Set 8 | labuhan
# Processing Record 17 of Set 8 | rosarito
# Processing Record 18 of Set 8 | chipata
# Processing Record 19 of Set 8 | ossora
# Processing Record 20 of Set 8 | oistins
# Processing Record 21 of Set 8 | eucaliptus
# Processing Record 22 of Set 8 | elat
# Processing Record 23 of Set 8 | porto novo
# Processing Record 24 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 8 | terekli-mekteb
# Processing Record 26 of Set 8 | kavieng
# Processing Record 27 of Set 8 | missoula
# Processing Record 28 of Set 8 | severo-kurilsk
# Processing Record 29 of Set 8 | broome
# Processing Record 30 of Set 8 | visnes
# Processing Record 31 of Set 8 | faya
# Processing Record 32 of Set 8 | harper
# Processing Record 33 of Set 8 | rundu
# Processing Record 34 of Set 8 | manokwari
# Processing Record 35 of Set 8 | zhanaozen
# Processing Record 36 of Set 8 | tabou
# Processing Record 37 of Set 8 | ereymentau
# Processing Record 38 of Set 8 | defiance
# Processing Record 39 of Set 8 | xining
# Processing Record 40 of Set 8 | le vauclin
# Processing Record 41 of Set 8 | paytug
# City not found. Skipping...
# Processing Record 42 of Set 8 | les cayes
# Processing Record 43 of Set 8 | janakkala
# Processing Record 44 of Set 8 | sao filipe
# Processing Record 45 of Set 8 | vuktyl
# Processing Record 46 of Set 8 | santa cruz de tenerife
# Processing Record 47 of Set 8 | vestmannaeyjar
# Processing Record 48 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 8 | jiangkou
# Processing Record 50 of Set 8 | general roca
# Processing Record 1 of Set 9 | leningradskiy
# Processing Record 2 of Set 9 | kimbe
# Processing Record 3 of Set 9 | camacha
# Processing Record 4 of Set 9 | malmesbury
# Processing Record 5 of Set 9 | okha
# Processing Record 6 of Set 9 | iqaluit
# Processing Record 7 of Set 9 | yumen
# Processing Record 8 of Set 9 | sawai madhopur
# Processing Record 9 of Set 9 | quelimane
# Processing Record 10 of Set 9 | san policarpo
# Processing Record 11 of Set 9 | mapiri
# Processing Record 12 of Set 9 | leshukonskoye
# Processing Record 13 of Set 9 | baykit
# Processing Record 14 of Set 9 | olinda
# Processing Record 15 of Set 9 | gravelbourg
# Processing Record 16 of Set 9 | iki-burul
# Processing Record 17 of Set 9 | partanna
# Processing Record 18 of Set 9 | asosa
# Processing Record 19 of Set 9 | bridgetown
# Processing Record 20 of Set 9 | ust-barguzin
# Processing Record 21 of Set 9 | jiuquan
# Processing Record 22 of Set 9 | nabire
# Processing Record 23 of Set 9 | dudinka
# Processing Record 24 of Set 9 | martapura
# Processing Record 25 of Set 9 | san miguel
# Processing Record 26 of Set 9 | tautira
# Processing Record 27 of Set 9 | waikuku
# Processing Record 28 of Set 9 | tuatapere
# Processing Record 29 of Set 9 | santa maria
# Processing Record 30 of Set 9 | lacdayan
# Processing Record 31 of Set 9 | zaozhuang
# Processing Record 32 of Set 9 | klyuchevskiy
# Processing Record 33 of Set 9 | san quintin
# Processing Record 34 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 35 of Set 9 | pithapuram
# Processing Record 36 of Set 9 | togur
# Processing Record 37 of Set 9 | matamoros
# Processing Record 38 of Set 9 | beyneu
# Processing Record 39 of Set 9 | bure
# Processing Record 40 of Set 9 | kaitangata
# Processing Record 41 of Set 9 | lagoa
# Processing Record 42 of Set 9 | benha
# City not found. Skipping...
# Processing Record 43 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 44 of Set 9 | vardo
# Processing Record 45 of Set 9 | monzon
# Processing Record 46 of Set 9 | stepnyak
# Processing Record 47 of Set 9 | aklavik
# Processing Record 48 of Set 9 | dubbo
# Processing Record 49 of Set 9 | kushmurun
# Processing Record 50 of Set 9 | kulhudhuffushi
# Processing Record 1 of Set 10 | fereydun kenar
# Processing Record 2 of Set 10 | talara
# Processing Record 3 of Set 10 | along
# Processing Record 4 of Set 10 | koyilandi
# City not found. Skipping...
# Processing Record 5 of Set 10 | savannah bight
# Processing Record 6 of Set 10 | vao
# Processing Record 7 of Set 10 | dabat
# Processing Record 8 of Set 10 | pakaur
# Processing Record 9 of Set 10 | sembakung
# Processing Record 10 of Set 10 | serenje
# Processing Record 11 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 12 of Set 10 | sao jose da coroa grande
# Processing Record 13 of Set 10 | terney
# Processing Record 14 of Set 10 | namie
# Processing Record 15 of Set 10 | college
# Processing Record 16 of Set 10 | bandarbeyla
# Processing Record 17 of Set 10 | boa vista
# Processing Record 18 of Set 10 | camargo
# Processing Record 19 of Set 10 | paamiut
# Processing Record 20 of Set 10 | castanos
# Processing Record 21 of Set 10 | muli
# Processing Record 22 of Set 10 | richards bay
# Processing Record 23 of Set 10 | lukiv
# Processing Record 24 of Set 10 | san jeronimo
# Processing Record 25 of Set 10 | narrabri
# Processing Record 26 of Set 10 | sandpoint
# Processing Record 27 of Set 10 | cairns
# Processing Record 28 of Set 10 | sechura
# Processing Record 29 of Set 10 | lebanon
# Processing Record 30 of Set 10 | kurilsk
# Processing Record 31 of Set 10 | mattru
# Processing Record 32 of Set 10 | aktash
# Processing Record 33 of Set 10 | quetigny
# Processing Record 34 of Set 10 | san pablo jocopilas
# Processing Record 35 of Set 10 | dukat
# Processing Record 36 of Set 10 | hukuntsi
# Processing Record 37 of Set 10 | vanavara
# Processing Record 38 of Set 10 | abeche
# Processing Record 39 of Set 10 | sao joao da barra
# Processing Record 40 of Set 10 | port moresby
# Processing Record 41 of Set 10 | belyy yar
# Processing Record 42 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 43 of Set 10 | haines junction
# Processing Record 44 of Set 10 | northam
# Processing Record 45 of Set 10 | khor
# Processing Record 46 of Set 10 | talgar
# Processing Record 47 of Set 10 | kurchum
# Processing Record 48 of Set 10 | sorong
# Processing Record 49 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 10 | cerro punta
# Processing Record 1 of Set 11 | pavilosta
# Processing Record 2 of Set 11 | atikokan
# Processing Record 3 of Set 11 | sangmelima
# Processing Record 4 of Set 11 | deputatskiy
# Processing Record 5 of Set 11 | victor harbor
# Processing Record 6 of Set 11 | eyl
# Processing Record 7 of Set 11 | berlevag
# Processing Record 8 of Set 11 | coos bay
# Processing Record 9 of Set 11 | inuvik
# Processing Record 10 of Set 11 | lensk
# Processing Record 11 of Set 11 | dillon
# Processing Record 12 of Set 11 | worthington
# Processing Record 13 of Set 11 | tura
# Processing Record 14 of Set 11 | burnie
# Processing Record 15 of Set 11 | zemio
# Processing Record 16 of Set 11 | kilindoni
# Processing Record 17 of Set 11 | mackay
# Processing Record 18 of Set 11 | hegang
# Processing Record 19 of Set 11 | kabalo
# Processing Record 20 of Set 11 | ukiah
# Processing Record 21 of Set 11 | yartsevo
# Processing Record 22 of Set 11 | hovd
# Processing Record 23 of Set 11 | senador jose porfirio
# Processing Record 24 of Set 11 | buritis
# Processing Record 25 of Set 11 | henties bay
# Processing Record 26 of Set 11 | basse
# Processing Record 27 of Set 11 | tlanchinol
# Processing Record 28 of Set 11 | sitka
# Processing Record 29 of Set 11 | olovyannaya
# Processing Record 30 of Set 11 | banda aceh
# Processing Record 31 of Set 11 | omboue
# Processing Record 32 of Set 11 | frumusita
# Processing Record 33 of Set 11 | palaikastron
# Processing Record 34 of Set 11 | san lawrenz
# Processing Record 35 of Set 11 | farah
# Processing Record 36 of Set 11 | shintomi
# Processing Record 37 of Set 11 | bernalillo
# Processing Record 38 of Set 11 | san andres
# Processing Record 39 of Set 11 | tokur
# Processing Record 40 of Set 11 | pochutla
# Processing Record 41 of Set 11 | north bend
# Processing Record 42 of Set 11 | jardim do serido
# Processing Record 43 of Set 11 | ortega
# Processing Record 44 of Set 11 | dakoro
# Processing Record 45 of Set 11 | eidsvag
# Processing Record 46 of Set 11 | baruun-urt
# Processing Record 47 of Set 11 | severo-yeniseyskiy
# Processing Record 48 of Set 11 | los llanos de aridane
# Processing Record 49 of Set 11 | moundsville
# Processing Record 50 of Set 11 | lewistown
# Processing Record 1 of Set 12 | santa clara
# Processing Record 2 of Set 12 | puerto baquerizo moreno
# Processing Record 3 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 4 of Set 12 | wajima
# Processing Record 5 of Set 12 | cordoba
# Processing Record 6 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 12 | santa isabel do rio negro
# Processing Record 8 of Set 12 | matagami
# Processing Record 9 of Set 12 | kewanee
# Processing Record 10 of Set 12 | duiwelskloof
# Processing Record 11 of Set 12 | arcachon
# Processing Record 12 of Set 12 | neiafu
# Processing Record 13 of Set 12 | nemuro
# Processing Record 14 of Set 12 | antofagasta
# Processing Record 15 of Set 12 | encruzilhada do sul
# Processing Record 16 of Set 12 | qingyuan
# Processing Record 17 of Set 12 | pangai
# Processing Record 18 of Set 12 | tlacotepec
# Processing Record 19 of Set 12 | miami
# Processing Record 20 of Set 12 | kieta
# Processing Record 21 of Set 12 | novoagansk
# Processing Record 22 of Set 12 | qianan
# Processing Record 23 of Set 12 | ouegoa
# Processing Record 24 of Set 12 | amudat
# Processing Record 25 of Set 12 | maloy
# Processing Record 26 of Set 12 | ibra
# Processing Record 27 of Set 12 | la paz
# Processing Record 28 of Set 12 | sabalgarh
# Processing Record 29 of Set 12 | madang
# Processing Record 30 of Set 12 | esperance
# Processing Record 31 of Set 12 | gao
# Processing Record 32 of Set 12 | channel-port aux basques
# Processing Record 33 of Set 12 | isangel
# Processing Record 34 of Set 12 | sola
# Processing Record 35 of Set 12 | jiangyou
# Processing Record 36 of Set 12 | voloshka
# Processing Record 37 of Set 12 | vanimo
# Processing Record 38 of Set 12 | phuket
# Processing Record 39 of Set 12 | omsukchan
# Processing Record 40 of Set 12 | yenagoa
# Processing Record 41 of Set 12 | sao paulo de olivenca
# Processing Record 42 of Set 12 | juigalpa
# Processing Record 43 of Set 12 | punta cardon
# Processing Record 44 of Set 12 | atascadero
# Processing Record 45 of Set 12 | westport
# Processing Record 46 of Set 12 | kovur
# Processing Record 47 of Set 12 | sawakin
# Processing Record 48 of Set 12 | avera
# Processing Record 49 of Set 12 | hojo
# Processing Record 50 of Set 12 | lishan
# Processing Record 1 of Set 13 | puttur
# Processing Record 2 of Set 13 | aksarka
# Processing Record 3 of Set 13 | jashpurnagar
# Processing Record 4 of Set 13 | kuala terengganu
# Processing Record 5 of Set 13 | saint-francois
# Processing Record 6 of Set 13 | dharchula
# Processing Record 7 of Set 13 | fougamou
# Processing Record 8 of Set 13 | lodja
# Processing Record 9 of Set 13 | krasnyy chikoy
# Processing Record 10 of Set 13 | leeston
# Processing Record 11 of Set 13 | singaraja
# Processing Record 12 of Set 13 | bilibino
# Processing Record 13 of Set 13 | huanren
# Processing Record 14 of Set 13 | belaya gora
# Processing Record 15 of Set 13 | labis
# Processing Record 16 of Set 13 | bluefield
# Processing Record 17 of Set 13 | egra
# Processing Record 18 of Set 13 | bhuj
# Processing Record 19 of Set 13 | muisne
# Processing Record 20 of Set 13 | fortuna
# Processing Record 21 of Set 13 | aporawan
# City not found. Skipping...
# Processing Record 22 of Set 13 | yar-sale
# Processing Record 23 of Set 13 | yatou
# Processing Record 24 of Set 13 | ilhabela
# Processing Record 25 of Set 13 | angoche
# Processing Record 26 of Set 13 | leh
# Processing Record 27 of Set 13 | hayden
# Processing Record 28 of Set 13 | khani
# Processing Record 29 of Set 13 | bumba
# Processing Record 30 of Set 13 | ginir
# Processing Record 31 of Set 13 | orlat
# Processing Record 32 of Set 13 | hammonton
# Processing Record 33 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 13 | trairi
# Processing Record 35 of Set 13 | tobermory
# Processing Record 36 of Set 13 | macas
# Processing Record 37 of Set 13 | stutterheim
# Processing Record 38 of Set 13 | boende
# Processing Record 39 of Set 13 | san juan
# Processing Record 40 of Set 13 | sharjah
# Processing Record 41 of Set 13 | oriximina
# Processing Record 42 of Set 13 | grobina
# Processing Record 43 of Set 13 | budogoshch
# Processing Record 44 of Set 13 | alihe
# Processing Record 45 of Set 13 | peace river
# Processing Record 46 of Set 13 | moscow
# Processing Record 47 of Set 13 | coolum beach
# Processing Record 48 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 49 of Set 13 | mnogovershinnyy
# Processing Record 50 of Set 13 | tangshan
# Processing Record 1 of Set 14 | de aar
# Processing Record 2 of Set 14 | halvad
# Processing Record 3 of Set 14 | divnomorskoye
# Processing Record 4 of Set 14 | mahibadhoo
# Processing Record 5 of Set 14 | santa marta
# Processing Record 6 of Set 14 | natal
# Processing Record 7 of Set 14 | mo i rana
# Processing Record 8 of Set 14 | sobolevo
# Processing Record 9 of Set 14 | huilong
# Processing Record 10 of Set 14 | monroe
# Processing Record 11 of Set 14 | nederland
# Processing Record 12 of Set 14 | kaberamaido
# Processing Record 13 of Set 14 | flinders
# Processing Record 14 of Set 14 | bethal
# Processing Record 15 of Set 14 | shingu
# Processing Record 16 of Set 14 | liverpool
# Processing Record 17 of Set 14 | taranto
# Processing Record 18 of Set 14 | miyako
# Processing Record 19 of Set 14 | teeli
# Processing Record 20 of Set 14 | pula
# Processing Record 21 of Set 14 | nocupetaro
# Processing Record 22 of Set 14 | douglas
# Processing Record 23 of Set 14 | orgun
# City not found. Skipping...
# Processing Record 24 of Set 14 | gizo
# Processing Record 25 of Set 14 | domoni
# Processing Record 26 of Set 14 | sao caetano de odivelas
# Processing Record 27 of Set 14 | puerto quijarro
# Processing Record 28 of Set 14 | kontagora
# Processing Record 29 of Set 14 | leshan
# Processing Record 30 of Set 14 | sisimiut
# Processing Record 31 of Set 14 | sao raimundo nonato
# Processing Record 32 of Set 14 | cazaje
# City not found. Skipping...
# Processing Record 33 of Set 14 | pinawa
# Processing Record 34 of Set 14 | santa cruz
# Processing Record 35 of Set 14 | cape canaveral
# Processing Record 36 of Set 14 | marawi
# Processing Record 37 of Set 14 | san-pedro
# Processing Record 38 of Set 14 | teluknaga
# Processing Record 39 of Set 14 | purnia
# Processing Record 40 of Set 14 | tongsa
# City not found. Skipping...
# Processing Record 41 of Set 14 | waddan
# Processing Record 42 of Set 14 | point pedro
# Processing Record 43 of Set 14 | tamandare
# Processing Record 44 of Set 14 | shubarkuduk
# Processing Record 45 of Set 14 | mayo
# Processing Record 46 of Set 14 | kavaratti
# Processing Record 47 of Set 14 | ratnagiri
# Processing Record 48 of Set 14 | luau
# Processing Record 49 of Set 14 | lima
# Processing Record 50 of Set 14 | bud
# Processing Record 1 of Set 15 | mount isa
# Processing Record 2 of Set 15 | san jose de rio tinto
# Processing Record 3 of Set 15 | garden city
# Processing Record 4 of Set 15 | mantua
# Processing Record 5 of Set 15 | buta
# Processing Record 6 of Set 15 | milkovo
# Processing Record 7 of Set 15 | lyngseidet
# Processing Record 8 of Set 15 | southbridge
# Processing Record 9 of Set 15 | koutiala
# Processing Record 10 of Set 15 | passo de camaragibe
# Processing Record 11 of Set 15 | laguna
# Processing Record 12 of Set 15 | sioux lookout
# Processing Record 13 of Set 15 | luwuk
# Processing Record 14 of Set 15 | tahe
# Processing Record 15 of Set 15 | necochea
# Processing Record 16 of Set 15 | volchansk
# Processing Record 17 of Set 15 | nhulunbuy
# Processing Record 18 of Set 15 | corn island
# Processing Record 19 of Set 15 | batagay
# Processing Record 20 of Set 15 | muzhi
# Processing Record 21 of Set 15 | seoul
# Processing Record 22 of Set 15 | najran
# Processing Record 23 of Set 15 | locri
# Processing Record 24 of Set 15 | lososina
# Processing Record 25 of Set 15 | makhu
# Processing Record 26 of Set 15 | abay
# Processing Record 27 of Set 15 | noumea
# Processing Record 28 of Set 15 | cervantes
# Processing Record 29 of Set 15 | kulu
# Processing Record 30 of Set 15 | kropotkin
# Processing Record 31 of Set 15 | arman
# Processing Record 32 of Set 15 | dipkarpaz
# City not found. Skipping...
# Processing Record 33 of Set 15 | apatou
# Processing Record 34 of Set 15 | tutoia
# Processing Record 35 of Set 15 | honiara
# Processing Record 36 of Set 15 | vyartsilya
# Processing Record 37 of Set 15 | waunakee
# Processing Record 38 of Set 15 | thinadhoo
# Processing Record 39 of Set 15 | tarakan
# Processing Record 40 of Set 15 | great yarmouth
# Processing Record 41 of Set 15 | soledade
# Processing Record 42 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 15 | maryborough
# Processing Record 44 of Set 15 | bartica
# Processing Record 45 of Set 15 | los alamos
# Processing Record 46 of Set 15 | sergeyevka
# Processing Record 47 of Set 15 | nybro
# Processing Record 48 of Set 15 | galle
# Processing Record 49 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 50 of Set 15 | muros
# Processing Record 1 of Set 16 | hofn
# Processing Record 2 of Set 16 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 16 | nicolas bravo
# Processing Record 4 of Set 16 | anadyr
# Processing Record 5 of Set 16 | lompoc
# Processing Record 6 of Set 16 | hailar
# Processing Record 7 of Set 16 | kendari
# Processing Record 8 of Set 16 | aleksandrovskiy zavod
# Processing Record 9 of Set 16 | marsh harbour
# Processing Record 10 of Set 16 | waipawa
# Processing Record 11 of Set 16 | barinas
# Processing Record 12 of Set 16 | novyy nekouz
# Processing Record 13 of Set 16 | maldegem
# Processing Record 14 of Set 16 | rongcheng
# Processing Record 15 of Set 16 | oyama
# Processing Record 16 of Set 16 | soderhamn
# Processing Record 17 of Set 16 | half moon bay
# Processing Record 18 of Set 16 | nichinan
# Processing Record 19 of Set 16 | jijiga
# Processing Record 20 of Set 16 | hamilton
# Processing Record 21 of Set 16 | puerto escondido
# Processing Record 22 of Set 16 | anton lizardo
# Processing Record 23 of Set 16 | fonte boa
# Processing Record 24 of Set 16 | gazojak
# Processing Record 25 of Set 16 | bressuire
# Processing Record 26 of Set 16 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 16 | ridgecrest
# Processing Record 28 of Set 16 | aragarcas
# Processing Record 29 of Set 16 | okandja
# City not found. Skipping...
# Processing Record 30 of Set 16 | floro
# Processing Record 31 of Set 16 | kariba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng       Description  Max Temp  Humidity  \
# 0         Dikson  73.5069   80.5464  scattered clouds     36.00        83
# 1         Atuona  -9.8000 -139.0333  scattered clouds     78.19        69
# 2   Batemans Bay -35.7167  150.1833     broken clouds     51.10        73
# 3         Albany  42.6001  -73.9662   overcast clouds     78.67        52
# 4  Saint Anthony  45.0205  -93.2180        light rain     75.25        67
# 5      Coihaique -45.5752  -72.0662  scattered clouds     41.61        93
# 6         Avarua -21.2078 -159.7750        few clouds     82.45        69
# 7           Lebu -37.6167  -73.6500   overcast clouds     50.94        87
# 8   Saint George  37.1041 -113.5841         clear sky     99.43         7
# 9         Dieppe  49.7500    1.1667     broken clouds     56.75        82
#
#    Cloudiness  Wind Speed Country
# 0          33        6.87      RU
# 1          38       20.13      PF
# 2          84        6.46      AU
# 3          86        1.01      US
# 4          80        1.99      US
# 5          40        3.44      CL
# 6          20       14.97      CK
# 7          87        6.69      CL
# 8           0        3.00      US
# 9          54        4.83      FR

# %%
# Order the Columns for easier readibility
city_data_new_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Description' ]
city_data_df = city_data_df[city_data_new_order]
city_data_df = city_data_df.rename(columns={"Description": "Current Description"})
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Dikson      RU  73.5069   80.5464     36.00        83          33
# 1         Atuona      PF  -9.8000 -139.0333     78.19        69          38
# 2   Batemans Bay      AU -35.7167  150.1833     51.10        73          84
# 3         Albany      US  42.6001  -73.9662     78.67        52          86
# 4  Saint Anthony      US  45.0205  -93.2180     75.25        67          80
# 5      Coihaique      CL -45.5752  -72.0662     41.61        93          40
# 6         Avarua      CK -21.2078 -159.7750     82.45        69          20
# 7           Lebu      CL -37.6167  -73.6500     50.94        87          87
# 8   Saint George      US  37.1041 -113.5841     99.43         7           0
# 9         Dieppe      FR  49.7500    1.1667     56.75        82          54
#
#    Wind Speed Current Description
# 0        6.87    scattered clouds
# 1       20.13    scattered clouds
# 2        6.46       broken clouds
# 3        1.01     overcast clouds
# 4        1.99          light rain
# 5        3.44    scattered clouds
# 6       14.97          few clouds
# 7        6.69     overcast clouds
# 8        3.00           clear sky
# 9        4.83       broken clouds

# %%
#Exporting data above into a CSV file

city_data_df.to_csv('WeatherPy_Database.csv')
